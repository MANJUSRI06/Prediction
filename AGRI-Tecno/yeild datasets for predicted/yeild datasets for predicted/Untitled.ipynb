# %%
import pandas as pd
df = pd.read_csv("\YEILD DATASETS FOR PREDICTED\crop_yield.csv")
   # or your real file path
print(df.shape)
print(df.columns.tolist())
print(df.isnull().sum())
print(df.describe().T)
import os
os.listdir()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\Y'
# <>:2: SyntaxWarning: invalid escape sequence '\Y'
# C:\Users\praga\AppData\Local\Temp\ipykernel_22868\1311297974.py:2: SyntaxWarning: invalid escape sequence '\Y'
#   df = pd.read_csv("\YEILD DATASETS FOR PREDICTED\crop_yield.csv")
# (19689, 10)
# ['Crop', 'Crop_Year', 'Season', 'State', 'Area', 'Production', 'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield']
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64
#                    count          mean           std      min        25%  \
# Crop_Year        19689.0  2.009128e+03  6.498099e+00  1997.00    2004.00
# Area             19689.0  1.799266e+05  7.328287e+05     0.50    1390.00
# Production       19689.0  1.643594e+07  2.630568e+08     0.00    1393.00
# ...

# %%
import joblib, pandas as pd
obj = joblib.load("models/linear_yield_model.pkl")
model, scaler, feats = obj["model"], obj["scaler"], obj["feature_names"]

new_df = pd.read_csv("data/new_rows.csv")   # must have same columns before encoding
# Preprocess same as training: impute numeric, one-hot to match training columns, align order
# Simple approach: keep only training feature columns
X_new = new_df[feats]
X_new_scaled = scaler.transform(X_new)
preds = model.predict(X_new_scaled)
print(preds)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import joblib, pandas as pd
# ----> 2 obj = joblib.load("models/linear_yield_model.pkl")
#       3 model, scaler, feats = obj["model"], obj["scaler"], obj["feature_names"]
#       5 new_df = pd.read_csv("data/new_rows.csv")   # must have same columns before encoding
#
# File E:\yeild datasets for predicted\venv\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
# ...
